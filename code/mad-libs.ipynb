# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/michael-borck/think-python-direct-ai/blob/main/code/mad-libs.ipynb)
#
# # Project: Mad Libs Generator
#
# *This is a starting point — the book walks you through building the full version step by step. Complete it as an exercise using the skills and techniques from the chapter.*
#
# *This notebook was generated from the book's project code. See the companion book for the full explanation and step-by-step development process.*

# %%
# Problem: Using unclear names
thing1 = input("Adjective: ")
thing2 = input("Noun: ")

# Solution: Descriptive names
size_adjective = input("Adjective for size: ")
animal_noun = input("Name an animal: ")
