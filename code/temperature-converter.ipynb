# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/michael-borck/think-python-direct-ai/blob/main/code/temperature-converter.ipynb)
#
# # Project: Temperature Converter
#
# *This notebook was generated from the book's project code. See the companion book for the full explanation and step-by-step development process.*

# %%
def main():
    """Run the temperature converter"""
    history = []  # Store conversions
    
    while True:
        display_menu()
        choice = get_user_choice()
        
        if choice == "8":
            break
        elif choice == "1":
            temp = get_temperature_input("Celsius")
            result = celsius_to_fahrenheit(temp)
            display_result(temp, result, "°C", "°F")
            history.append({"from": temp, "to": result, "type": "C→F"})
